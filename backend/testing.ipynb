# %%
import requests

url = "http://127.0.0.1:5000/api/batch"

payload = {
        "farm_name": "BananaCorp",
        "harvest_date": "XXXX-XX-XX",
        "quantity_kg": 6767, 
        "latitude": 10.45,
        "longitude": 67.67,
        "grade": "spectacular",
        "produce": "bananas"
        }

reponse = requests.post(url, json=payload)

reponse.json()
# Out:
# {'batch_uuid': 'BX616sb1647', 'message': 'Batch has been initialized'}

# %%
url = "http://127.0.0.1:5000/api/transfer"

payload = { 
"batch_uuid": "BX616sb1647",
"latitude": 10.45,
"longitude": 67.67,
"actor_name": "bananacorp distributors",
"timestamp": "6767-68-67T67:67:67Z",
"action": "Received from farm"
}

reponse = requests.post(url, json=payload)

reponse.json()
# Out:
# {'message': 'Transfer recorded Audit: Passed'}

# %%
url = "http://127.0.0.1:5000/api/batch/BX616sb1647"

reponse = requests.get(url)

reponse.json()
# Out:
# [{'action': 'Harvested',
#   'actor_name': 'BananaCorp',
#   'latitude': 10.45,
#   'longitude': 67.67,
#   'timestamp': '2025-11-09T01:35:23.243552Z'},
#  {'action': 'Received from farm',
#   'actor_name': 'bananacorp distributors',
#   'latitude': 10.45,
#   'longitude': 67.67,
#   'timestamp': '2025-11-09T01:35:36.168094Z'}]

# %%
import requests

url = "https://cornhackshaa.onrender.com/api/batch/hack"

reponse = requests.post(url, "S21--AB1631")

reponse.json()
# Out:
# {'error': "'NoneType' object has no attribute 'id'"}
